# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
import pickle

# %% [markdown]
# #### Fetching data

# %%
url_dataset = 'https://drive.google.com/file/d/1BlvYVY3f4S8zU34njCJWlVmuhJX8Yq1F/view?usp=drive_link'
file_id = url_dataset.split('/')[-2]

dwn_url = 'https://drive.google.com/uc?id=' + file_id
df = pd.read_csv(dwn_url)

# %%
# df.shape

# %%
df.head()
# Out:
#    Unnamed: 0                                               Text   Language
# 0           0  സ്വയരക്ഷാബോധത്തോടും സ്വാതന്ത്ര്യത്തോടും കൂടി ജ...  Malayalam
# 1           1  രാഷ്ട്രീയങ്ങളല്ലാത്ത കുറ്റങ്ങൾക്കും ഐക്യരാഷ്ട്...  Malayalam
# 2           2  രാഷ്ട്രീയങ്ങളല്ലാത്ത കുറ്റങ്ങള്‍ക്കും ഐക്യരാഷ്...  Malayalam
# 3           3  തുല്യമായ പ്രവൃത്തിയെടുത്താൽ തുല്യമായ ശമ്പളത്തി...  Malayalam
# 4           4  സമുദായത്തിലെ സാംസ്കാരിക സംരംഭങ്ങളില്‍ പങ്കെടുക...  Malayalam

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df['Language'].value_counts()
# Out:
# Language
# English     2443
# French      2072
# Spanish     1897
# Russian     1750
# Dutch       1604
#             ...
# Yoruba        57
# Somali        57
# Burmese       56
# Bhojpuri      56
# Magahi        53
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# #### Cleaning text - removing special chars, numbers and spaces

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', '', text)
    return text

# %%
texts = df['Text']
language = df['Language']

texts = [preprocess_text(text) for text in texts]

# %%
# len(language.unique())

# %%
X_train, X_test, y_train, y_test = train_test_split(texts, language, test_size=0.2, random_state=42)

# %% [markdown]
# #### Converting text to numerical features using TfidfVectorizer
# #### Using Mutinomial Naive Bayes model for language detection

# %%
param_grid = {
    'vectorizer__ngram_range': [(1,1), (1,2), (2,3)],  # Unigrams, bigrams, char-level ngrams
    'vectorizer__analyzer': ['char', 'word'],
    # 'vectorizer__max_df': [0.7, 0.9],  # Ignore overly common words
    # 'vectorizer__min_df': [1, 2],  # Ignore rare words
    # 'vectorizer__use_idf': [True, False],  # With/without inverse document frequency
    'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100]  # Laplace smoothing parameter
}
cv = StratifiedKFold(n_splits=5, shuffle=True)

# %%
pipeline = Pipeline(steps=[('vectorizer', TfidfVectorizer()), ('model', MultinomialNB())])
model = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=cv, scoring='accuracy', verbose=2)

# %%
model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.7s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.5s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.7s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.2s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.7s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.7s
# [CV] END model__alpha=0.001, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.6s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.001, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.5s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.9s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.1s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.9s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.2s
# [CV] END model__alpha=0.01, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  10.7s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.01, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.5s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.2s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.2s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.5s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.1s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.2s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  13.7s
# [CV] END model__alpha=0.1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  13.0s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.5s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.5s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=0.1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.7s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   2.0s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   6.6s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   6.1s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.7s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   6.1s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.8s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  13.2s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=1, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=1, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.6s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.7s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.8s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.4s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.2s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.2s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  13.1s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  13.5s
# [CV] END model__alpha=10, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  15.6s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.5s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.6s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.5s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.0s
# [CV] END model__alpha=10, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   2.0s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.4s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.9s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.9s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 1); total time=   1.8s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.8s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   6.0s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(1, 2); total time=   5.6s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.1s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.0s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.0s
# [CV] END model__alpha=100, vectorizer__analyzer=char, vectorizer__ngram_range=(2, 3); total time=  11.3s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.4s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 1); total time=   0.3s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(1, 2); total time=   0.3s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.0s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# [CV] END model__alpha=100, vectorizer__analyzer=word, vectorizer__ngram_range=(2, 3); total time=   0.1s
# C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 30 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\pipeline.py", line 654, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\pipeline.py", line 588, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\joblib\memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\pipeline.py", line 1551, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\feature_extraction\text.py", line 2104, in fit_transform
#     X = super().fit_transform(raw_documents)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\feature_extraction\text.py", line 1376, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\feature_extraction\text.py", line 1282, in _count_vocab
#     raise ValueError(
# ValueError: empty vocabulary; perhaps the documents only contain stop words
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.79633529 0.93039652 0.95907932 0.07826029 0.07826029        nan
#  0.7840974  0.87852434 0.92476436 0.07826029 0.07826029        nan
#  0.73330305 0.75937824 0.84591308 0.07645241 0.07645241        nan
#  0.63891118 0.67107052 0.7806209  0.07328864 0.07328864        nan
#  0.53801758 0.58338837 0.64829825 0.06988145 0.06988145        nan
#  0.37840282 0.39467376 0.41859324 0.06758683 0.06758683        nan]
#   warnings.warn(
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=Pipeline(steps=[('vectorizer', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              param_grid={'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'vectorizer__analyzer': ['char', 'word'],
#                          'vectorizer__ngram_range': [(1, 1), (1, 2), (2, 3)]},
#              scoring='accuracy', verbose=2)

# %%
# Print best parameters and accuracy
print(f"Best Parameters: {model.best_params_}")
print(f"Best Accuracy: {model.best_score_:.4f}")
best_model = model.best_estimator_
best_model
# Out:
# Best Parameters: {'model__alpha': 0.001, 'vectorizer__analyzer': 'char', 'vectorizer__ngram_range': (2, 3)}
# Best Accuracy: 0.9591
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='char', ngram_range=(2, 3))),
#                 ('model', MultinomialNB(alpha=0.001))])

# %%
# with open("../Language_Detection/language_detector_model.pkl", "rb") as file:
#     model = pickle.load(file)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 96.14796273119177

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.96      0.99      0.98       300
#      Bengali       1.00      1.00      1.00        21
#     Bhojpuri       0.00      0.00      0.00         8
#    Bulgarian       1.00      0.58      0.74        12
#      Burmese       1.00      1.00      1.00         8
#      Cebuano       1.00      0.94      0.97        16
#      Chinese       1.00      0.98      0.99       206
#        Czech       1.00      1.00      1.00        11
#       Danish       0.97      0.84      0.90        86
#        Dutch       0.96      0.98      0.97       317
#      English       0.87      1.00      0.93       499
#     Estonian       0.98      0.96      0.97       183
#       French       0.98      0.99      0.98       437
#       German       0.98      0.95      0.96        95
#        Greek       1.00      1.00      1.00        72
#     Gujarati       1.00      1.00      1.00        10
#      Haitian       1.00      0.96      0.98        24
#        Hausa       1.00      1.00      1.00        35
#   Hiligaynon       1.00      0.89      0.94         9
#        Hindi       0.87      1.00      0.93       208
#    Hungarian       1.00      1.00      1.00         9
#         Igbo       1.00      1.00      1.00         9
#   Indonesian       0.93      0.97      0.95       224
#      Italian       0.96      0.95      0.96       128
#     Japanese       1.00      0.99      1.00       251
#     Javanese       1.00      0.63      0.78        30
#      Kannada       1.00      1.00      1.00        98
#       Kazakh       1.00      1.00      1.00        12
#        Khmer       1.00      1.00      1.00        14
#       Korean       1.00      0.99      1.00       187
#        Latin       0.98      0.92      0.95       202
#       Magahi       0.00      0.00      0.00        10
#     Maithili       1.00      0.38      0.56        13
#    Malayalam       1.00      1.00      1.00       146
#      Marathi       1.00      0.75      0.86        16
#      Panjabi       1.00      1.00      1.00        10
#      Persian       0.99      1.00      1.00       209
#       Polish       1.00      1.00      1.00        15
#   Portugeese       0.98      0.70      0.81       148
#    Portugese       0.73      0.94      0.82       179
#   Portuguese       1.00      0.24      0.39        25
#       Pushto       1.00      0.96      0.98       208
#     Romanian       1.00      0.99      1.00       224
#      Russian       0.98      1.00      0.99       357
#      Saraiki       1.00      0.80      0.89        10
#        Shona       1.00      1.00      1.00        14
#      Sinhala       1.00      1.00      1.00        13
#       Somali       1.00      1.00      1.00         9
#      Spanish       0.99      0.96      0.98       378
#      Swedish       0.93      0.99      0.96       214
#     Sweedish       0.96      0.89      0.92       140
#      Tagalog       1.00      1.00      1.00        10
#        Tamil       1.00      1.00      1.00       315
#        Tatar       1.00      1.00      1.00        10
#       Telugu       1.00      1.00      1.00        10
#         Thai       1.00      0.98      0.99       213
#      Turkish       1.00      0.98      0.99       301
#    Ukrainian       1.00      1.00      1.00        13
#         Urdu       0.99      0.93      0.96       231
#   Vietnamese       1.00      1.00      1.00         7
#       Yoruba       1.00      1.00      1.00        13
#         Zulu       1.00      1.00      1.00         9
#
#     accuracy                           0.96      7191
#    macro avg       0.95      0.90      0.92      7191
# weighted avg       0.96      0.96      0.96      7191
# C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
precision = precision_score(y_test, y_pred, average='weighted') * 100
recall = recall_score(y_test, y_pred, average='weighted') * 100
accuracy = accuracy_score(y_test, y_pred) * 100

print(f"Accuracy: {accuracy:.2f}%")
print(f"Precision: {precision:.2f}%")
print(f"Recall: {recall:.2f}%")
# Out:
# Accuracy: 96.15%
# Precision: 96.28%
# Recall: 96.15%
# C:\Users\hiami\anaconda3\envs\study\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
new_text = ["Ciao buon pomeriggio",
            "Guten abend!",
            "وہ تبدیلی بنیں جو آپ دنیا میں دیکھنا چاہتے ہیں", 
            "நம்பிக்கை, ஊக்கம், மோட்டிவேஷன். நீங்கள் பொருளீட்டுவது நலமாய் வாழ்வதற்கு, மன அழுத்தத்தினால் உங்களை நீங்களே அழிப்பதற்கல்ல.", 
            "努力は夢中に勝てない。", 
            "टेक्स्ट एक आम शब्द है जिसका मतलब अक्सर लिखित शब्दों या ऐसी चीज़ों से होता है जिनमें बहुत ज़्यादा लिखा होता है।"]
new_text_preprocessed = [preprocess_text(text) for text in new_text]

predicted_language = best_model.predict(new_text_preprocessed)
print(f"Predicted Language: {predicted_language}")
# Out:
# Predicted Language: ['Italian' 'German' 'Urdu' 'Tamil' 'Japanese' 'Hindi']

# %%
pickle.dump(best_model, open("language_detector_model.pkl", "wb"))
